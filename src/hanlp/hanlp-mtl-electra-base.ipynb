# %% [markdown]
# # HanLP MTL dùng ELECTRA_BASE
# Chạy công cụ phân tích ngữ pháp chương tiết trên Chivi.

# %%
# @title ## Bước 1: Cài đặt thư viện
# @markdown Cần chạy trước khi chạy các bước khác.
# %pip install hanlp requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: hanlp in /home/nipin/.local/lib/python3.10/site-packages (2.1.0b50)
# Requirement already satisfied: requests in /home/nipin/.local/lib/python3.10/site-packages (2.31.0)
# Requirement already satisfied: transformers>=4.1.1 in /home/nipin/.local/lib/python3.10/site-packages (from hanlp) (4.31.0)
# Requirement already satisfied: hanlp-downloader in /home/nipin/.local/lib/python3.10/site-packages (from hanlp) (0.0.25)
# Requirement already satisfied: termcolor in /home/nipin/.local/lib/python3.10/site-packages (from hanlp) (2.3.0)
# Requirement already satisfied: hanlp-common>=0.0.19 in /home/nipin/.local/lib/python3.10/site-packages (from hanlp) (0.0.19)
# Requirement already satisfied: toposort==1.5 in /home/nipin/.local/lib/python3.10/site-packages (from hanlp) (1.5)
# Requirement already satisfied: torch>=1.6.0 in /home/nipin/.local/lib/python3.10/site-packages (from hanlp) (2.0.1)
# Requirement already satisfied: sentencepiece>=0.1.91 in /home/nipin/.local/lib/python3.10/site-packages (from hanlp) (0.1.99)
# Requirement already satisfied: tokenizers==0.11.6 in /home/nipin/.local/lib/python3.10/site-packages (from hanlp) (0.11.6)
# Requirement already satisfied: pynvml in /home/nipin/.local/lib/python3.10/site-packages (from hanlp) (11.5.0)
# Requirement already satisfied: hanlp-trie>=0.0.4 in /home/nipin/.local/lib/python3.10/site-packages (from hanlp) (0.0.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/nipin/.local/lib/python3.10/site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nipin/.local/lib/python3.10/site-packages (from requests) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/nipin/.local/lib/python3.10/site-packages (from requests) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/nipin/.local/lib/python3.10/site-packages (from requests) (3.4)
# Requirement already satisfied: phrasetree in /home/nipin/.local/lib/python3.10/site-packages (from hanlp-common>=0.0.19->hanlp) (0.0.8)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/nipin/.local/lib/python3.10/site-packages (from torch>=1.6.0->hanlp) (11.7.91)
# Requirement already satisfied: filelock in /home/nipin/.local/lib/python3.10/site-packages (from torch>=1.6.0->hanlp) (3.12.2)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/nipin/.local/lib/python3.10/site-packages (from torch>=1.6.0->hanlp) (2.14.3)
# Requirement already satisfied: typing-extensions in /home/nipin/.local/lib/python3.10/site-packages (from torch>=1.6.0->hanlp) (4.7.1)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/nipin/.local/lib/python3.10/site-packages (from torch>=1.6.0->hanlp) (11.10.3.66)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/nipin/.local/lib/python3.10/site-packages (from torch>=1.6.0->hanlp) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/nipin/.local/lib/python3.10/site-packages (from torch>=1.6.0->hanlp) (11.4.0.1)
# Requirement already satisfied: triton==2.0.0 in /home/nipin/.local/lib/python3.10/site-packages (from torch>=1.6.0->hanlp) (2.0.0)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/nipin/.local/lib/python3.10/site-packages (from torch>=1.6.0->hanlp) (11.7.4.91)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/nipin/.local/lib/python3.10/site-packages (from torch>=1.6.0->hanlp) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/nipin/.local/lib/python3.10/site-packages (from torch>=1.6.0->hanlp) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/nipin/.local/lib/python3.10/site-packages (from torch>=1.6.0->hanlp) (8.5.0.96)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/nipin/.local/lib/python3.10/site-packages (from torch>=1.6.0->hanlp) (10.9.0.58)
# Requirement already satisfied: sympy in /home/nipin/.local/lib/python3.10/site-packages (from torch>=1.6.0->hanlp) (1.12)
# Requirement already satisfied: jinja2 in /home/nipin/.local/lib/python3.10/site-packages (from torch>=1.6.0->hanlp) (3.1.2)
# Requirement already satisfied: networkx in /home/nipin/.local/lib/python3.10/site-packages (from torch>=1.6.0->hanlp) (3.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/nipin/.local/lib/python3.10/site-packages (from torch>=1.6.0->hanlp) (11.7.99)
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->hanlp) (0.37.1)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->hanlp) (59.6.0)
# Requirement already satisfied: lit in /home/nipin/.local/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.6.0->hanlp) (16.0.6)
# Requirement already satisfied: cmake in /home/nipin/.local/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.6.0->hanlp) (3.26.4)
# Requirement already satisfied: numpy>=1.17 in /home/nipin/.local/lib/python3.10/site-packages (from transformers>=4.1.1->hanlp) (1.25.2)
# Requirement already satisfied: safetensors>=0.3.1 in /home/nipin/.local/lib/python3.10/site-packages (from transformers>=4.1.1->hanlp) (0.3.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/nipin/.local/lib/python3.10/site-packages (from transformers>=4.1.1->hanlp) (6.0.1)
# Requirement already satisfied: tqdm>=4.27 in /home/nipin/.local/lib/python3.10/site-packages (from transformers>=4.1.1->hanlp) (4.66.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /home/nipin/.local/lib/python3.10/site-packages (from transformers>=4.1.1->hanlp) (0.16.4)
# Requirement already satisfied: packaging>=20.0 in /home/nipin/.local/lib/python3.10/site-packages (from transformers>=4.1.1->hanlp) (23.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/nipin/.local/lib/python3.10/site-packages (from transformers>=4.1.1->hanlp) (2023.8.8)
# Requirement already satisfied: fsspec in /home/nipin/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers>=4.1.1->hanlp) (2023.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/nipin/.local/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->hanlp) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/nipin/.local/lib/python3.10/site-packages (from sympy->torch>=1.6.0->hanlp) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#@title ## Bước 2: Tải xuống dữ liệu
# @markdown Tải xuống thư viện liên quan, bước này có thể sẽ hơi lâu, nếu hệ thống bận.

import os, re, requests, getpass

URL = "https://chivi.app/_wn"
CLIENT = requests.Session()

os.environ["HANLP_HOME"] = ".hanlp" # đổi địa chỉ lưu models
import hanlp

# tải xuống dữ liệu 
MTL_TYPE = hanlp.pretrained.mtl.CLOSE_TOK_POS_NER_SRL_DEP_SDP_CON_ELECTRA_BASE_ZH
MTL_TASK = hanlp.load(MTL_TYPE)

# lấy thông tin chương cuối cùng
def get_max_ch_no(wn_id, sname):
  url = f"{URL}/seeds/{wn_id}/{sname}/brief"
  res = CLIENT.get(url)
  return res.json()["chap_count"]

# đảm bảo dữ liệu cây ngữ pháp chỉ có một dòng
def render_con_data(con_data):
  output = ''

  for con_line in con_data:
    output += re.sub('\\n(\\s+)', ' ', str(con_line))
    output += '\n'

  return output

# phản hồi tới người dùng, bỏ qua phần đệm (chỉ chứa tên chương) mỗi chương
def print_msg(message, p_idx):
  if p_idx > 0:
    print(message % p_idx)

def invoke_mtl_task(lines):
  try: 
    # thử chạy phân tích tất cả các dòng
    return MTL_TASK(lines)
  except:
    # nếu tràn bộ nhớ, thử phân tích từng dòng một
    mtl_data = MTL_TASK([lines[0]])

    for line in lines[1:]:
      mtl_line = MTL_TASK(line)

      for key in mtl_data:
        mtl_data[key].append(mtl_line[key])

    return mtl_data

# phân tích ngữ pháp từng phần mỗi chương
def analyze_text(ptext, wn_id, sname, ch_no, cksum, p_idx):
  mtl_data = invoke_mtl_task(ptext.split('\n'))
  print_msg("  - Đã phân tích xong phần %s, đang tải lên...", p_idx)

  json = {
    'wn_id': wn_id, 'sname': sname,
    'ch_no': ch_no, 'cksum': cksum,
    'p_idx': p_idx, '_algo': 'hmeb',
    'con_text': render_con_data(mtl_data["con"]),
    'mtl_json': mtl_data.to_json(),
  }

  url = "https://chivi.app/_wn/anlzs/chaps"
  res = CLIENT.post(url, json = json)

  if res.status_code > 300:
    print(f"  Đăng tải thất bại: {res.text}")

def analyze_book(wn_id, sname, chmin = 1, chmax = 1, force = False):
  for ch_no in range(chmin, chmax + 1):
    print(f"\n- Tải xuống text gốc chương [{ch_no}] nguồn [{sname}] truyện [{wn_id}]:")

    url = f"{URL}/texts/{wn_id}/{sname}/{ch_no}/parts"
    res = CLIENT.get(url).json()

    cksum = res["cksum"]
    parts = res["parts"]
    _hmeb = res["_hmeb"]

    print(f"  Đã lấy xuống text gốc, chương chia {len(parts) - 1} phần, checksum: [{cksum}].")
    print()

    for p_idx, ptext in enumerate(parts):
      if _hmeb[p_idx] == True and not force:
        print_msg("  - Phần %s đã có trên hệ thống, bỏ qua.", p_idx)
        continue

      try:
        analyze_text(ptext, wn_id, sname, ch_no, cksum, p_idx)
      except Exception as inst:
        print(inst)
# Out:
# Downloading https://file.hankcs.com/hanlp/mtl/close_tok_pos_ner_srl_dep_sdp_con_ernie_gram_base_aug_20210904_145403.zip to .hanlp/mtl/close_tok_pos_ner_srl_dep_sdp_con_ernie_gram_base_aug_20210904_145403.zip
#  27% 448.0 MiB   1.1 MiB/s ETA:  5 m  1 s [=========                           ]
# Download failed due to KeyboardInterrupt().
# Please re-try or download it to .hanlp/mtl/close_tok_pos_ner_srl_dep_sdp_con_ernie_gram_base_aug_20210904_145403.zip by yourself with:
#
# 	wget https://file.hankcs.com/hanlp/mtl/close_tok_pos_ner_srl_dep_sdp_con_ernie_gram_base_aug_20210904_145403.zip -O .hanlp/mtl/close_tok_pos_ner_srl_dep_sdp_con_ernie_gram_base_aug_20210904_145403.zip
#
# See also https://hanlp.hankcs.com/docs/install.html#install-models for instructions.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 14
#      12 # tải xuống dữ liệu
#      13 MTL_TYPE = hanlp.pretrained.mtl.CLOSE_TOK_POS_NER_SRL_DEP_SDP_CON_ERNIE_GRAM_ZH
# ---> 14 MTL_TASK = hanlp.load(MTL_TYPE)
#      16 # lấy thông tin chương cuối cùng
#      17 def get_max_ch_no(wn_id, sname):
#
# File ~/.local/lib/python3.10/site-packages/hanlp/__init__.py:43, in load(save_dir, verbose, **kwargs)
#      41     from hanlp_common.constant import HANLP_VERBOSE
#      42     verbose = HANLP_VERBOSE
# ---> 43 return load_from_meta_file(save_dir, 'meta.json', verbose=verbose, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/hanlp/utils/component_util.py:32, in load_from_meta_file(save_dir, meta_filename, transform_only, verbose, **kwargs)
#      30 identifier = save_dir
#      31 load_path = save_dir
# ---> 32 save_dir = get_resource(save_dir)
#      33 if save_dir.endswith('.json'):
#      34     meta_filename = os.path.basename(save_dir)
#
# File ~/.local/lib/python3.10/site-packages/hanlp/utils/io_util.py:337, in get_resource(path, save_dir, extract, prefix, append_location, verbose)
#     335     realpath += compressed
#     336 if not os.path.isfile(realpath):
# --> 337     path = download(url=path, save_path=realpath, verbose=verbose)
#     338 else:
#     339     path = realpath
#
# File ~/.local/lib/python3.10/site-packages/hanlp/utils/io_util.py:185, in download(url, save_path, save_dir, prefix, append_location, verbose)
#     183     elif hasattr(e, 'args') and e.args and isinstance(e.args, tuple) and isinstance(e.args[0], str):
#     184         e.args = (e.args[0] + '\n' + remove_color_tag(message),) + e.args[1:]
# --> 185     raise e from None
#     186 remove_file(save_path)
#     187 os.rename(tmp_path, save_path)
#
# File ~/.local/lib/python3.10/site-packages/hanlp/utils/io_util.py:155, in download(url, save_path, save_dir, prefix, append_location, verbose)
#     153     if verbose:
#     154         downloader.subscribe(DownloadCallback(show_header=False))
# --> 155     downloader.start_sync()
#     156 except BaseException as e:
#     157     remove_file(tmp_path)
#
# File ~/.local/lib/python3.10/site-packages/hanlp_downloader/down.py:114, in Downloader.start_sync(self)
#     111 if self.__state != Downloader.INIT:
#     112     raise RuntimeError('Download has already been started.')
# --> 114 self.run()
#
# File ~/.local/lib/python3.10/site-packages/hanlp_downloader/down.py:206, in Downloader.run(self)
#     204 except KeyboardInterrupt as e:
#     205     self.stop()
# --> 206     raise e
#     208 for chunk in self.__chunks:
#     209     if chunk.error:
#
# File ~/.local/lib/python3.10/site-packages/hanlp_downloader/down.py:203, in Downloader.run(self)
#     201     while any(chunk.thread.is_alive() for chunk in self.__chunks):
#     202         for chunk in self.__chunks:
# --> 203             chunk.thread.join(1)
#     204 except KeyboardInterrupt as e:
#     205     self.stop()
#
# File /usr/lib/python3.10/threading.py:1100, in Thread.join(self, timeout)
#    1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
# -> 1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /usr/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:

# %%
#@title ## Bước 3: Đăng nhập vào hệ thống
# @markdown Bạn hãy cung cấp địa chỉ email + mật khẩu tài khoản Chivi để hệ thống định danh

# đăng nhập vào hệ thống
def do_login():
  print("\nThông tin đăng nhập Chivi:")

  # @markdown Địa chỉ hòm thư:
  email = '' # @param {type: "string"}
  # @markdown Mật khẩu:
  upass = '' # @param {type: "string", hidden: true}

  if email == '':
    print("Hòm thư:", end=' ')
    email = input().strip()

  if upass == '':  
    upass = getpass.getpass("Mật khẩu: ").strip()

  json = {'email': email, 'upass': upass}
  res = CLIENT.post("https://chivi.app/_db/_user/log-in", json=json)

  if res.status_code < 300:
    user = res.json()["uname"]
    print(f"Xin chào {user}!")
    print()
  else:
    print("Đăng nhập thất bại, mời thử lại!")
    do_login()
    
do_login()

# %%
#@title ## Bước 4: Phân tích ngữ pháp

# @markdown *ID bộ truyện:* Con số đầu tiên trên địa chỉ bộ truyện. Ví dụ truyện có địa chỉ là https://chivi.app/wn/4-quy-bi-chi-chu/ thì ID bộ truyện là 4
# @markdown *Nguồn chương:* Tên danh sách chương, nguồn chính thức tên là ~chivi, nguồn tạm thời tên là ~draft, các nguồn cá nhân bắt đầu bằng @ tiếp đó là tên đăng nhập.

# @markdown ID bộ truyện:
wn_id = 0 # @param {type: "integer"}

# @markdown Nguồn chương:
sname = '~chivi' # @param {type: "string"}

# @markdown Chương bắt đầu
chmin = 1 # @param {type: "integer"}

# @markdown Chương kết thúc
chmax = 0 # @param {type: "integer"}

# @markdown Phân tích lại dù có trên hệ thống
force = False # @param {type: "boolean"}

if wn_id == 0:
  print('Nhập ID bộ truyện:', end=' ')
  wn_id = int(input().strip())

if sname == '':
  print("Nhập nguồn chương:", end=' ')
  sname = input().strip()

if sname == '':
  sname = "~chivi" 

print("...Kiểm tra dữ liệu...", end=' ')

url = f"{URL}/seeds/{wn_id}/{sname}/brief"
res = requests.get(url).json()

total = res["chap_count"]
print(f"hoàn thành, nguồn truyện có tổng cộng {total} chương")

if chmax < chmin:
  chmax = total

if chmin < 1:
  chmin = 1

print(f"Bạn sẽ chạy chương trình phân tích dữ liệu các chương từ {chmin} tới {chmax} của bộ truyện {wn_id}")

analyze_book(wn_id, sname, chmin, chmax, force)
